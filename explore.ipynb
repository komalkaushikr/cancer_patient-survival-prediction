# %%
import pandas as pd
df = pd.read_csv(r"E:\Desktop\cancer\archive\india_cancer_patients_2022_2025.csv")
#print(df.describe())
print(df.info())
print(df['Cancer_Type'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Patient_ID       100000 non-null  object
#  1   Age              100000 non-null  int64
#  2   Gender           100000 non-null  object
#  3   State            100000 non-null  object
#  4   City             100000 non-null  object
#  5   Hospital_Name    100000 non-null  object
#  6   Cancer_Type      100000 non-null  object
#  7   Stage            100000 non-null  object
#  8   Treatment_Type   100000 non-null  object
#  9   Diagnosis_Date   100000 non-null  object
#  10  Survival_Months  100000 non-null  float64
#  11  Status           100000 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 9.2+ MB
# None
# Cancer_Type
# Breast Cancer        28169
# Oral Cancer          16259
# Cervical Cancer      13881
# Lung Cancer          12046
# ...

# %% [markdown]
# Age is normally distributed around 54. Survival is right-skewed, so I'd report the median. Cancer type is dominated by breast cancer at 28%, with the top four types covering 70% of records - a class imbalance I'd need to handle before any predictive modeling.
